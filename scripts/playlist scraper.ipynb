# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import json
import pandas as pd

url = "https://youtube.com/playlist?list=PLZEl0b5BNrnHW-JJFWpoAnRlPgY-70pp-"
r = requests.get(url)
soup = bs(r.text,'html.parser')
res = soup.find_all("ytd-playlist-video-renderer")
titles = []
for video in res:
    titles.append(video.get('title'))

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html darker-dark-theme="" darker-dark-theme-deprecate="" lang="en" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing="">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="AlgsH67ctYlMR3JYAxEnGfvsoFo41AMqAg6wRHHXOpWAfD54ZCfTPBclxnFT4Gc8IUX4pq6Xfo0esDuOt+WH3wIAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2ODA2NTI3OTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/>
#   <script nonce="l7AW5P6vR_ADzo9e-HxVrg">
#    var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# ...

# %%
i = 0
for l in soup.find_all("script"):
    print("script", i, "\n\n\n")
    print(l)
    i += 1
# Out:
# script 0
#
#
#
# <script nonce="l7AW5P6vR_ADzo9e-HxVrg">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20230124.09.00');</script>
# script 1
#
#
#
# <script nonce="l7AW5P6vR_ADzo9e-HxVrg">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;
# ...

# %%
print(type(key_script))
#print(key_script)
print(key_script.contents[0])
# Out:
# <class 'bs4.element.Tag'>
# ...

# %%
key_script = soup.find_all("script")[33]
key_script_json = str(key_script.contents[0]).replace("var ytInitialData = ", "")[0:439559]

# %%
print(key_script_json)
# Out:
# {"responseContext":{"serviceTrackingParams":[{"service":"GFEEDBACK","params":[{"key":"browse_id","value":"VLPLZEl0b5BNrnHW-JJFWpoAnRlPgY-70pp-"},{"key":"browse_id_prefix","value":""},{"key":"logged_in","value":"0"},{"key":"e","value":"1714254,23804281,23880830,23880836,23882685,23885487,23918597,23946420,23966208,23983296,23986019,23998056,24004644,24007246,24034168,24036948,24077241,24080738,24120819,24135310,24140247,24161116,24162919,24164186,24166867,24169501,24181174,24186125,24187043,24187377,24197450,24211177,24219713,24228033,24241378,24248092,24255165,24255543,24255545,24262346,24263796,24267564,24268142,24279196,24281896,24283015,24283093,24288045,24288664,24290971,24291857,24294553,24390675,24391537,24396645,24404640,24406313,24407190,24414719,24415864,24415866,24416239,24417873,24421966,24423039,24426636,24428902,24429093,24432417,24432469,24433679,24436009,24436455,24437575,24439360,24439483,24440132,24445833,24447671,24449113,24449721,24449913,24450200,24450250,24451032
# ...

# %%
playlist_dict = json.loads(key_script_json)

# %%
playlist_dict.keys()
# Out:
# dict_keys(['responseContext', 'contents', 'header', 'alerts', 'metadata', 'trackingParams', 'topbar', 'microformat', 'sidebar'])

# %%
section_renderer = playlist_dict['contents']["twoColumnBrowseResultsRenderer"]["tabs"][0]['tabRenderer']['content']['sectionListRenderer']['contents']

# %%
video_list = section_renderer[0]['itemSectionRenderer']['contents'][0]['playlistVideoListRenderer']['contents']

# %%
len(video_list)
# Out:
# 81

# %% [markdown]
# ## Successfully isolated the video list

# %%
dancing_queen = video_list[1]

# %%
dancing_queen['playlistVideoRenderer'].keys()
# Out:
# dict_keys(['videoId', 'thumbnail', 'title', 'index', 'shortBylineText', 'lengthText', 'navigationEndpoint', 'lengthSeconds', 'trackingParams', 'isPlayable', 'menu', 'thumbnailOverlays', 'videoInfo'])

# %%
dancing_queen['playlistVideoRenderer']['title']['runs'][0]['text']
# Out:
# 'Dancing Queen'

# %%
dancing_queen['playlistVideoRenderer']['shortBylineText']['runs'][0]['text']
# Out:
# 'ABBA'

# %%
'youtube.com' + dancing_queen['playlistVideoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url']
# Out:
# 'youtube.com/watch?v=YkLLcIKhJ64&list=PLZEl0b5BNrnHW-JJFWpoAnRlPgY-70pp-&index=2'

# %%
def get_video_info(video_element):
    song_title = video_element['playlistVideoRenderer']['title']['runs'][0]['text']
    song_byline = video_element['playlistVideoRenderer']['shortBylineText']['runs'][0]['text']
    
    song_url = 'youtube.com' + video_element['playlistVideoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url']
    
    if song_byline[-8:] == ' - Topic':
        song_byline = song_byline.replace(' - Topic', '')
    if ' Official' in song_byline:
        song_byline = song_byline.replace(' Official', '')
        
    
    return({"title": song_title, "artist": song_byline, "url": song_url})

# %%
# this function gets a list of "video objects" from a youtube playlist HTML.

def get_playlist_dict(soup_text):
    # the script we want should be the 33rd script, or it is for this trial
    key_script = soup_text.find_all("script")[33]
    # delete the initial variable setting so we just have the JSON object
    key_script_json = str(key_script.contents[0]).replace("var ytInitialData = ", "")
    
    # delete the final semicolon at the end (if it exists)
    if key_script_json[-1] == ";":
        key_script_json = key_script_json[:-1]
    
    # convert the string into JSON
    playlist_dict = json.loads(key_script_json)
    
    return(playlist_dict)

def get_video_list(playlist_dict):
    
    # extract the meaningful information
    tab_renderer = playlist_dict['contents']["twoColumnBrowseResultsRenderer"]["tabs"][0]['tabRenderer']['content']
    section_renderer = tab_renderer['sectionListRenderer']['contents']
    video_list = section_renderer[0]['itemSectionRenderer']['contents'][0]['playlistVideoListRenderer']['contents']
    
    return(video_list)

# %%
len(get_video_list(soup))
# Out:
# 81

# %%
get_video_info(get_video_list(soup)[0])
# Out:
# {'title': 'Beautiful Noise', 'artist': 'Neil Diamond'}

# %% [markdown]
# **TODO: get playlist title/participant**

# %%
playlist_dict.keys()
# Out:
# dict_keys(['responseContext', 'contents', 'header', 'alerts', 'metadata', 'trackingParams', 'topbar', 'microformat', 'sidebar'])

# %%
playlist_dict['metadata']['playlistMetadataRenderer']['title']
# Out:
# 'BFOR Energizing'

# %%
def get_participant_info(playlist_dict):
    # get the title of the playlist
    playlist_title = playlist_dict['metadata']['playlistMetadataRenderer']['title']
    
    # separate into participant and type of playlist
    info_list = playlist_title.split()
    
    return({'participant': info_list[0], 'playlist_type':info_list[1].lower()})

# %%
def get_full_playlist_info(playlist_link, info=False):
    
    # get the HTML from the link
    r = requests.get(playlist_link)
    soup = bs(r.text,'html.parser')

    # construct the playlist dictionary
    if info: print('extracting playlist dict')
    full_playlist_dict = get_playlist_dict(soup)
    
    # get the participant info
    if info: print('extracting participant info')
    participant_info = get_participant_info(full_playlist_dict)
    
    # get the video info
    if info: print('extracting vide list')
    video_list = get_video_list(full_playlist_dict)
    
    extracted_videos = []
    
    current_video = 0
    for video in video_list:
        if current_video > 99:
            break
            
        if info: print('adding video', current_video, 'of ', len(video_list), 'videos.')
        extracted_videos.append(get_video_info(video))
        
        current_video += 1
    
    if info: print('building dataframe.')
    # construct dataframe
    playlist_df = pd.DataFrame(extracted_videos)
    playlist_df['participant'] = participant_info['participant']
    playlist_df['playlist_type'] = participant_info['playlist_type']
    
    return playlist_df

# %%
playlist_df_1 = get_full_playlist_info("https://youtube.com/playlist?list=PLZEl0b5BNrnHW-JJFWpoAnRlPgY-70pp-")

# %%
print(playlist_df_1)
# Out:
#                                             title             artist  \
# 0                                 Beautiful Noise       Neil Diamond
# 1                                   Dancing Queen               ABBA
# 2                             Take A Chance On Me               ABBA
# 3                                        Y.M.C.A.     Village People
# 4                Single Ladies (Put a Ring on It)            Beyoncé
# ..                                            ...                ...
# 76                                          Misty      Johnny Mathis
# 77  Where Have All The Flowers Gone? (Remastered)  The Kingston Trio
# 78                                         Mariah  The Kingston Trio
# 79                      You Make Me Feel so Young   Rosemary Clooney
# 80   Island In the Sun (From "Island In the Sun")    Harry Belafonte
#
#                                                   url participant  \
# 0   youtube.com/watch?v=55FsVRUKQDA&list=PLZEl0b5B...        BFOR
# ...

# %% [markdown]
# # Get all playlists of the mind lab

# %%
playlists = ['https://www.youtube.com/watch?v=wqGTKBkElhY&list=PLZEl0b5BNrnE5x7uGgG7BCTqUpYljJoAY',
            'https://www.youtube.com/watch?v=14XjtcpjKAw&list=PLZEl0b5BNrnGDSDKIuWHRIlIGHF6oZSPw',
            'https://www.youtube.com/watch?v=tY33uoXvn2M&list=PLZEl0b5BNrnF76fnmOtAU40pJUfsX87h5',
            'https://www.youtube.com/watch?v=KYiUSalSjS0&list=PLZEl0b5BNrnEl4-qtxMPqdvW0dPkWVAWF',
            'https://www.youtube.com/watch?v=Ptk_1Dc2iPY&list=PLZEl0b5BNrnHHvq3uG_2fE4-LxOTo8t-W',
            'https://www.youtube.com/watch?v=22xfYppK-Jc&list=PLZEl0b5BNrnFtddsakBmlApKu3Zpwjq7e',
            'https://www.youtube.com/watch?v=irl89Gmcv8c&list=PLZEl0b5BNrnF7sSgjK8-2tDTnv_hmxSJd',
            'https://www.youtube.com/watch?v=9A_2WFx8FEU&list=PLZEl0b5BNrnEQcY0DRTUDjmGyxTeT1yss',
            'https://www.youtube.com/watch?v=U7ivAZqWKH0&list=PLZEl0b5BNrnHjTQe90Ez7bqj4oPL0zbFh',
            'https://www.youtube.com/watch?v=Ht_BfhweF4I&list=PLZEl0b5BNrnHb9Q0w6oohGprgAcdD_E49',
            'https://www.youtube.com/watch?v=iX_TFkut1PM&list=PLZEl0b5BNrnG4IGnV2NRwTUs4-pxejsCp',
            'https://www.youtube.com/watch?v=xYnAqYk8MQg&list=PLZEl0b5BNrnFTJD1mES8kJcnRsPAtBqba',
            'https://www.youtube.com/watch?v=2t5VNI0XlwY&list=PLZEl0b5BNrnECqChUTyzQ7M5ZL4-G6V9T',
            'https://www.youtube.com/watch?v=55FsVRUKQDA&list=PLZEl0b5BNrnHW-JJFWpoAnRlPgY-70pp-',
            'https://www.youtube.com/watch?v=AlDuNqWKDak&list=PLZEl0b5BNrnHx4DO2pOUAsohHEFlH5vJb',
            'https://www.youtube.com/watch?v=7kfYOGndVfU&list=PLZEl0b5BNrnFqqJ1TY_9SxEHkG7JohPIM',
            'https://www.youtube.com/watch?v=ryA6eHZNnXY&list=PLZEl0b5BNrnHJEDTjJV4OPIBSygsf2dpq',
            'https://www.youtube.com/watch?v=SbenaOqv4yQ&list=PLZEl0b5BNrnGKR98EHwE3L3a0Xmu1emhy',
            'https://www.youtube.com/watch?v=I6na1H4i7OY&list=PLZEl0b5BNrnGA_EIcxB6WABjOlo8q0bag',
            'https://www.youtube.com/watch?v=Vld1gTq6kH8&list=PLZEl0b5BNrnHMaCBgOb-ZBS4mNm5P5x9g',
            'https://www.youtube.com/watch?v=raPlwBVQ7hU&list=PLZEl0b5BNrnGHSo6w0BgmTm8Zh_girXmy',
            'https://www.youtube.com/watch?v=vsGsCvJWEo8&list=PLZEl0b5BNrnGQoBHE1YYIGFBnXn6sxari',
            'https://www.youtube.com/watch?v=zTeD3RWvE6A&list=PLZEl0b5BNrnEm_0LXMg66fgZAI62VqLOB',
            'https://www.youtube.com/watch?v=MTZgE8D8a9E&list=PLZEl0b5BNrnEXz2-nIIOjjBolV3qlHxxx',
            'https://www.youtube.com/watch?v=y1r--05n0tk&list=PLZEl0b5BNrnHxgPzyJ82L1gpWQHTkNK9S',
            'https://www.youtube.com/watch?v=BXtPycm5dGc&list=PLZEl0b5BNrnEFYSoc3q-n1ZstSoPOeJAI',
            'https://www.youtube.com/watch?v=jrqK7-uEMS8&list=PLZEl0b5BNrnEbOB_5PNN6auYcI3dNowKV',
            'https://www.youtube.com/watch?v=hjygPa_4ua4&list=PLZEl0b5BNrnHG6OUdCtcLlO6321RJN-iE',
            'https://www.youtube.com/watch?v=uNv_Bu_L6C8&list=PLZEl0b5BNrnFxxeM5hfocnw7AeVPqzW0O',
            # next batch of newly unlisted videos start here
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnELCxjLR6WE3QHMxY1vLZNk',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnGKE5EdORZlLdB3rWs9kzI0',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFe00nOTYtRK0eTpM99LiPc',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnF0bkhkIEcs9Qibh53nBwIS',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFwdz20bw1dbkNOcfx-NRIk',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnEr8mzixkAcyP6WhAvek3Gz',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnEr8mzixkAcyP6WhAvek3Gz',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFOMOXInvpPw2JavfzG8K0t',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFfBjbNsJJl8baCrGZAk4Hj',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnERY-yemjEqqw4DdgwUQxuu',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnGwdaxyJ9WhkDlaDlx9IQgh',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFDGS9X5EqGmx_FIStFfzuG',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnHV0GfqO6YUT23cwmhEIPsW',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnE8X15tJCbNIakhs1Q7-Thv',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnEZ5UpBGo3OA3qMweT09UXu',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnHeNWl6vdmHQPAr0aRazwUC',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFAN00JF6GDYAtkTPGRFD1T',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnGfrIGmyouJUdodLU5FM5s4',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFODpPu_IjbpI4pLwrpne35',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnGLz_LqzG5YmfRuLshpl72-',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFFLzrrpWFFUfZloNtVw4Bo',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnEP8LzV9qfVZ2PPh4AzmErj',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnHzOt2Y-4kyv0nv_3fY4Eji',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnE51RbEEUXGYGlnzb1N09FR',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnGwfBBVx3HPq9TpriMfbcow',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFENbiLaXsUNFFBjbLxYwC8',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFZivilbIDOPTYzyeELeaso',
             'https://www.youtube.com/playlist?list=PLZEl0b5BNrnFn8co0ksokEPmCTTlv3k2g']

# %%
playlist_df_list = []

for playlist in playlists:
    formatted_playlist = re.sub('watch\?v=.*\&', 'playlist?', playlist)
    print(formatted_playlist)
    
    playlist_df_list.append(get_full_playlist_info(formatted_playlist))
# Out:
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnE5x7uGgG7BCTqUpYljJoAY
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnGDSDKIuWHRIlIGHF6oZSPw
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnF76fnmOtAU40pJUfsX87h5
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnEl4-qtxMPqdvW0dPkWVAWF
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnHHvq3uG_2fE4-LxOTo8t-W
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnFtddsakBmlApKu3Zpwjq7e
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnF7sSgjK8-2tDTnv_hmxSJd
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnEQcY0DRTUDjmGyxTeT1yss
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnHjTQe90Ez7bqj4oPL0zbFh
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnHb9Q0w6oohGprgAcdD_E49
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnG4IGnV2NRwTUs4-pxejsCp
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnFTJD1mES8kJcnRsPAtBqba
# https://www.youtube.com/playlist?list=PLZEl0b5BNrnECqChUTyzQ7M5ZL4-G6V9T
# ...

# %%
global_playlist_df = pd.concat(playlist_df_list)

# %%
global_playlist_df
# Out:
#                                                 title  \
# 0   "Golden Lady" - #OffAir with Louis Cato and Th...
# 1   Mozart: Requiem In D Minor, K.626 - 3. Sequent...
# 2   Ein deutsches Requiem, Op. 45: I. Selig sind, ...
# 3   Ein deutsches Requiem, Op. 45: IV. Wie lieblic...
# 4                               Bridge Over The Stars
# ..                                                ...
# 95  Love Is Here -  The Futures -  Gamble ZS72502 ...
# 96         "When You Needed Roses" The Dazz Band 80's
# 97                         FOREVER MORE - Enchantment
# 98                                          First Man
# 99                                         Speechless
#
#                                 artist  \
# 0   The Late Show with Stephen Colbert
# 1                    Vienna Singverein
# 2                   Dresdner Kreuzchor
# 3                   Dresdner Kreuzchor
# 4                         Keiko Matsui
# ..                                 ...
# ...

# %% [markdown]
# ## GOT ALL DATA FOR PARTICIPANTS

# %%
len(global_playlist_df['participant'].unique())
# Out:
# 28

# %%
global_playlist_df[['participant', 'playlist_type']].drop_duplicates()
# Out:
#   participant playlist_type
# 0        EKAS      relaxing
# 0        EKAS    energizing
# 0        JMCG    energizing
# 0        JMCG      relaxing
# 0        GHER      relaxing
# 0        GHER    energizing
# 0        JDEN    energizing
# 0        JDEN      relaxing
# 0        DMUN    energizing
# 0        DMUN      relaxing
# 0        NLEN    energizing
# 0        TSTA      relaxing
# 0        TSTA    energizing
# 0        BFOR    energizing
# 0        BFOR      relaxing
# 0        AEHR      relaxing
# 0        AEHR    energizing
# 0        GSHA      relaxing
# 0        GSHA    energizing
# 0        ASHA    energizing
# 0        ASHA      relaxing
# 0        LJAC    energizing
# 0        LJAC      relaxing
# 0        EHER    energizing
# 0        EHER      relaxing
# 0        SCAE    energizing
# 0        SCAE      relaxing
# 0        FKEE    energizing
# 0        FKEE      relaxing
# 0        EROS    energizing
# 0        DCAT      relaxing
# 0        DCAT    energizing
# ...

# %%
global_playlist_df.to_csv('/Users/peterbenson/Documents/MIND Lab Peter Benson 2023/data/participant_playlists.csv')

# %% [markdown]
# **Below: a tricky example of >100 videos**

# %%
r = requests.get('https://www.youtube.com/playlist?list=PLZEl0b5BNrnFqqJ1TY_9SxEHkG7JohPIM')
tricky_soup = bs(r.text, 'html.parser')

tricky_dict = get_playlist_dict(tricky_soup)
tricky_video_list = get_video_list(tricky_dict)

# %%
print(tricky_video_list[0])
# Out:
# {'playlistVideoRenderer': {'videoId': '7kfYOGndVfU', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/7kfYOGndVfU/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLAr8nLESpTMYZvOx6RTm48g1K_Spg', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/7kfYOGndVfU/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLA5vxfKB30etm5LEjxih6kEZ9tPVQ', 'width': 196, 'height': 110}, {'url': 'https://i.ytimg.com/vi/7kfYOGndVfU/hqdefault.jpg?sqp=-oaymwEjCPYBEIoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAjSEN4k8iJ1bJO04SBiktG_Yf06A', 'width': 246, 'height': 138}, {'url': 'https://i.ytimg.com/vi/7kfYOGndVfU/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLD-aQ6ZZBJTkLmsbGFE_mg9CK5ctg', 'width': 336, 'height': 188}]}, 'title': {'runs': [{'text': 'Moondance (2013 Remaster)'}], 'accessibility': {'accessibilityData': {'label': 'Moondance (2013 Remaster) by Van Morrison 5 years 
# ...

# %%
curr_v = 0
for video in tricky_video_list:
    print(curr_v, get_video_info(video))
    curr_v += 1
# Out:
# 0 {'title': 'Moondance (2013 Remaster)', 'artist': 'Van Morrison'}
# 1 {'title': 'Paul Simon - You Can Call Me Al (Official Video)', 'artist': 'Paul Simon'}
# 2 {'title': 'Piano Man', 'artist': 'Billy Joel'}
# 3 {'title': 'Penny Lane (Remastered 2015)', 'artist': 'The Beatles'}
# 4 {'title': 'Suite for Flute and Jazz Piano Trio, by Claude Bolling.', 'artist': 'Rodney Leinberger'}
# 5 {'title': 'Petrushka, First Tableau: The Shrovetide Fair (Remastered)', 'artist': 'Igor Stravinsky'}
# 6 {'title': "The Sorcerer's Apprentice", 'artist': 'Leopold Stokowski'}
# 7 {'title': 'The Water Is Wide', 'artist': 'Bill Mize'}
# 8 {'title': 'I Am A Man Of Constant Sorrow (Radio Edit)', 'artist': 'Soggy Bottom Boys'}
# 9 {'title': "Ain't No Sunshine", 'artist': 'Bill Withers'}
# 10 {'title': "Isn't She Lovely", 'artist': 'Stevie Wonder'}
# 11 {'title': 'Black Magic Woman', 'artist': 'Santana'}
# 12 {'title': 'Evil Ways', 'artist': 'Santana'}
# 13 {'title': 'Samba Pa Ti', 'artist': 'Santana'}
# ...

# %% [markdown]
# **PROBLEM:** how to extract from playlists with more than 100 videos.
